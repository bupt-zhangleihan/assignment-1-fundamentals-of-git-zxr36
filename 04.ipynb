# %% [markdown]
# ## Introduction to Probability and Statistics
# ## Assignment
#
# In this assignment, we will use the dataset of diabetes patients taken [from here](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../../data/diabetes.tsv",sep='\t')
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# In this dataset, columns as the following:
# * Age and sex are self-explanatory
# * BMI is body mass index
# * BP is average blood pressure
# * S1 through S6 are different blood measurements
# * Y is the qualitative measure of disease progression over one year
#
# Let's study this dataset using methods of probability and statistics.
#
# ### Task 1: Compute mean values and variance for all values

# %%
pd.DataFrame([df.mean(),df.var()],index=['Mean','Variance']).head()
# Out:
#                 AGE       SEX        BMI          BP           S1          S2
# Mean       48.51810  1.468326  26.375792   94.647014   189.140271  115.439140  \
# Variance  171.84661  0.249561  19.519798  191.304401  1197.717241  924.955494
#
#                   S3        S4        S5          S6            Y
# Mean       49.788462  4.070249  4.641411   91.260181   152.133484
# Variance  167.293585  1.665261  0.272892  132.165712  5943.331348

# %% [markdown]
# ### Task 2: Plot boxplots for BMI, BP and Y depending on gender

# %%
for col in ['BMI','BP','Y']:
    df.boxplot(column=col,by='SEX')
plt.show()

# %% [markdown]
# ### Task 3: What is the the distribution of Age, Sex, BMI and Y variables?

# %%
for col in ['AGE','SEX','BMI','Y']:
    df[col].hist()
    plt.show()

# %% [markdown]
# ### Task 4: Test the correlation between different variables and disease progression (Y)
#
# > **Hint** Correlation matrix would give you the most useful information on which values are dependent.

# %%
fig, ax = plt.subplots(1,3,figsize=(10,5))
for i,n in enumerate(['BMI','S5','BP']):
    ax[i].scatter(df['Y'],df[n])
    ax[i].set_title(n)
plt.show()

# %% [markdown]
# ### Task 5: Test the hypothesis that the degree of diabetes progression is different between men and women

# %%
from scipy.stats import ttest_ind

tval, pval = ttest_ind(df.loc[df['SEX']==1,['Y']], df.loc[df['SEX']==2,['Y']],equal_var=False)
print(f"T-value = {tval[0]:.2f}\nP-value: {pval[0]}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\29429\Desktop\人工智能与数据挖掘\第二次作业\06.ipynb 单元格 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/29429/Desktop/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E4%B8%8E%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E7%AC%AC%E4%BA%8C%E6%AC%A1%E4%BD%9C%E4%B8%9A/06.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> from scipy.stats import ttest_ind
#       <a href='vscode-notebook-cell:/c%3A/Users/29429/Desktop/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E4%B8%8E%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E7%AC%AC%E4%BA%8C%E6%AC%A1%E4%BD%9C%E4%B8%9A/06.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> tval, pval = ttest_ind(df.loc[df['SEX']==1,['Y']], df.loc[df['SEX']==2,['Y']],equal_var=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/29429/Desktop/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E4%B8%8E%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/%E7%AC%AC%E4%BA%8C%E6%AC%A1%E4%BD%9C%E4%B8%9A/06.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> print(f"T-value = {tval[0]:.2f}\nP-value: {pval[0]}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:70
#      67 from numpy import __version__ as __numpy_version__
#      69 # Import numpy symbols to scipy name space (DEPRECATED)
# ---> 70 from ._lib.deprecation import _deprecated
#      71 import numpy as np
#      72 _msg = ('scipy.{0} is deprecated and will be removed in SciPy 2.0.0, '
#      73         'use numpy.{0} instead')
#
# ModuleNotFoundError: No module named 'scipy._lib'
